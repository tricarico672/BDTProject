# %%
import datetime
import time

# %%
ex = datetime.time(6, 20, 50)

# %%
print(ex)
# Out:
# 06:20:50

# %%
time.time()
# Out:
# 1746278859.455318

# %%
dt = datetime.datetime(2025, 5, 3, 14, 30, 15)
seconds = (dt - dt.replace(hour=0, minute=0, second=0, microsecond=0)).total_seconds()
seconds
# Out:
# 52215.0

# %%
import json

# %%
with open("route_to_stops.json", "r") as f:
    route_stop_map = json.load(f)

# %%
from datetime import datetime, timedelta
import time

# %%
timedelta(seconds=2 * 3000)
# Out:
# datetime.timedelta(seconds=6000)

# %%
app_start = datetime(2025, 1, 1, 6, 0, 0)
app_start + timedelta(seconds=2 * 3000)
# Out:
# datetime.datetime(2025, 1, 1, 7, 40)

# %%
time.time()
# Out:
# 1746378071.740155

# %%
time.time() + 2
# Out:
# 1746378074.0208168

# %%
if not None:
    print('hello')
# Out:
# hello
